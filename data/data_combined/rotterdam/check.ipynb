# %%
import pandas as pd
import os

# %%
import os
import pandas as pd

# # First, let's see what files we're dealing with
# print("Files in directory:")
# for file in os.listdir():
#     print(file)

# Then try to read each file with error handling
for file in os.listdir():
    if file.endswith('.csv'):  # Only process CSV files
        print(f"\nTrying to read {file}:")
        try:
            # # First try to peek at the file content
            # with open(file, 'r') as f:
            #     print("First few lines of file:")
            #     for i, line in enumerate(f):
            #         if i < 5:  # Print first 5 lines
            #             print(f"Line {i+1}: {line.strip()}")
            
            # Then try to read with pandas
            df = pd.read_csv(file, sep=';', on_bad_lines='warn')  # Skip bad lines
            # print(f"\nShape of dataframe: {df.shape}")
            # print("\nNull values count:")
            print(df.isnull().sum())
            
        except Exception as e:
            print(f"Error reading {file}: {str(e)}")
# Out:
# Trying to read val_2023_combined_u.csv:
# DateTime    0
# NO2         0
# O3          0
# P           0
# SQ          0
# WD          0
# Wvh         0
# dewP        0
# temp        0
# dtype: int64
#
# Trying to read val_2022_combined_u.csv:
# DateTime    0
# NO2         0
# O3          0
# P           0
# SQ          0
# WD          0
# Wvh         0
# dewP        0
# temp        0
# dtype: int64
#
# Trying to read train_2022_combined_u.csv:
# DateTime    0
# NO2         0
# O3          0
# P           0
# SQ          0
# WD          0
# Wvh         0
# dewP        0
# temp        0
# dtype: int64
#
# Trying to read train_2017_combined_u.csv:
# DateTime    0
# NO2         0
# O3          0
# P           0
# SQ          0
# WD          0
# Wvh         0
# dewP        0
# temp        0
# dtype: int64
#
# Trying to read val_2023_combined_y.csv:
# DateTime    0
# NO2         0
# O3          0
# dtype: int64
#
# Trying to read train_2020_combined_y.csv:
# DateTime    0
# NO2         0
# ...
